# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import r2_score, mean_absolute_error, mean_squared_error
import tensorflow as tf
from tensorflow.keras import models, layers, Model
from tensorflow.keras.optimizers import AdamW
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from tensorflow.keras import regularizers
import os
import random
import matplotlib.pyplot as plt
import warnings
from scipy import stats

os.environ['CUDA_VISIBLE_DEVICES'] = '0'
print("!!! FORCING SCRIPT TO RUN ON GPU 0 ONLY !!!")

gpus = tf.config.experimental.list_physical_devices('GPU')
if gpus:
    try:
        for gpu in gpus:
            tf.config.experimental.set_memory_growth(gpu, True)
        print(f"Enabled memory growth for {len(gpus)} GPUs")
    except RuntimeError as e:
        print(e)

warnings.filterwarnings('ignore')

# --- 1. ULTRA SETUP AND REPRODUCIBILITY ---
seed_value = 42
os.environ['PYTHONHASHSEED'] = str(seed_value)
os.environ['TF_DETERMINISTIC_OPS'] = '1'
random.seed(seed_value)
np.random.seed(seed_value)
tf.random.set_seed(seed_value)

# --- 2. DATA LOADING & PREPARATION ---
print(" =================== Starting Fine-Tuning =================== ")
try:
    df_main = pd.read_csv('6059_rows.csv')
    df_magpie = pd.read_csv('magpie_features.csv') 
    print("Successfully loaded '6059_rows.csv' and 'magpie_features.csv'")
except FileNotFoundError as e:
    print(f"Error: Could not find data files. {e}")
    exit()

print(" =================== Step 1/5: Aligning data sources =================== ")
df_main = df_main.dropna(subset=['debye_temperature'])
df_aligned = pd.merge(df_main, df_magpie, on='formula_sp', how='inner')
magpie_cols = [col for col in df_magpie.columns if col != 'formula_sp']
X_magpie_unscaled = df_aligned[magpie_cols].values

print(" =================== Step 2/5: Loading 3D .npy data =================== ")
X_cnn_list = []
y_list = []
input_dir = 'input_cnn'
found_formulas = []
for index, row in df_aligned.iterrows():
    file_path = os.path.join(input_dir, f"{row['formula_sp']}_latent.npy")
    if os.path.exists(file_path):
        X_cnn_list.append(np.load(file_path))
        y_list.append(row['debye_temperature'])
        found_formulas.append(row['formula_sp'])

df_aligned = df_aligned[df_aligned['formula_sp'].isin(found_formulas)].reset_index(drop=True)
X_magpie = df_aligned[magpie_cols].values
X_cnn = np.array(X_cnn_list)
y = np.array(y_list)

print(" =================== Step 3/5: Applying data cleaning =================== ")
def remove_outliers_advanced(X_cnn_in, X_magpie_in, y_in):
    y_finite_mask = np.isfinite(y_in)
    X_cnn_in = X_cnn_in[y_finite_mask]; X_magpie_in = X_magpie_in[y_finite_mask]; y_in = y_in[y_finite_mask]
    Q1 = np.percentile(y_in, 25); Q3 = np.percentile(y_in, 75); IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR; upper_bound = Q3 + 1.5 * IQR
    outlier_mask = (y_in >= lower_bound) & (y_in <= upper_bound)
    y_filtered = y_in[outlier_mask]
    if len(y_filtered) == 0 or np.std(y_filtered) == 0:
        return X_cnn_in, X_magpie_in, y_in
    else:
        return X_cnn_in[outlier_mask], X_magpie_in[outlier_mask], y_in[outlier_mask]

X_cnn, X_magpie, y = remove_outliers_advanced(X_cnn, X_magpie_unscaled, y)
print(f"Final data shape after cleaning: {X_cnn.shape}")

# --- 4. FEATURE ENGINEERING & SCALING ---
print(" =================== Step 4/5: Scaling data =================== ")
X_cnn_scaled = X_cnn / np.max(X_cnn) if np.max(X_cnn) != 0 else X_cnn
scaler_magpie = StandardScaler()
X_magpie_scaled = scaler_magpie.fit_transform(X_magpie)
scaler_y = MinMaxScaler() 
y_scaled = scaler_y.fit_transform(y.reshape(-1, 1)).flatten()
print("Data scaling complete.")

# --- 5. DATA SPLITTING ---
print(" =================== Step 5/5: Creating final data splits =================== ")
indices = np.arange(X_cnn_scaled.shape[0])
train_indices, test_indices = train_test_split(indices, test_size=0.2, random_state=seed_value)
train_indices, val_indices = train_test_split(train_indices, test_size=0.2, random_state=seed_value)

def split_data(data, train_idx, val_idx, test_idx):
    return data[train_idx], data[val_idx], data[test_idx]

X_cnn_train, X_cnn_val, X_cnn_test = split_data(X_cnn_scaled, train_indices, val_indices, test_indices)
X_magpie_train, X_magpie_val, X_magpie_test = split_data(X_magpie_scaled, train_indices, val_indices, test_indices)
y_train, y_val, y_test = split_data(y_scaled, train_indices, val_indices, test_indices)

train_inputs = {"input_layer": X_cnn_train, "Magpie_Input": X_magpie_train}
val_inputs = {"input_layer": X_cnn_val, "Magpie_Input": X_magpie_val}
test_inputs = {"input_layer": X_cnn_test, "Magpie_Input": X_magpie_test}

print(f"3D Train/Val/Test: {X_cnn_train.shape}, {X_cnn_val.shape}, {X_cnn_test.shape}")
print(f"Magpie Train/Val/Test: {X_magpie_train.shape}, {X_magpie_val.shape}, {X_magpie_test.shape}")

# --- 6. LOAD AND PREPARE MODEL FOR FINE-TUNING ---
print(" =================== Step 6/6: Loading and preparing model for Full Fine-Tuning =================== ")

@tf.keras.utils.register_keras_serializable()
class DualAttention3D(layers.Layer):
    def __init__(self, reduction_ratio=16, **kwargs): super(DualAttention3D, self).__init__(**kwargs); self.reduction_ratio = reduction_ratio
    def build(self, input_shape):
        self.channels = input_shape[-1]; self.global_avg_pool=layers.GlobalAveragePooling3D(); self.global_max_pool=layers.GlobalMaxPooling3D()
        self.dense1=layers.Dense(units=max(self.channels // self.reduction_ratio, 8), activation='relu'); self.dense2=layers.Dense(units=self.channels, activation='sigmoid')
        self.conv1=layers.Conv3D(2, 3, padding='same', activation='relu'); self.conv2=layers.Conv3D(1, 3, padding='same', activation='sigmoid')
        super(DualAttention3D, self).build(input_shape)
    def call(self, inputs):
        avg_pool=self.global_avg_pool(inputs); max_pool=self.global_max_pool(inputs)
        avg_pool=layers.Reshape((1,1,1,self.channels))(avg_pool); max_pool=layers.Reshape((1,1,1,self.channels))(max_pool)
        channel_avg=self.dense2(self.dense1(avg_pool)); channel_max=self.dense2(self.dense1(max_pool)); channel_attention=layers.Add()([channel_avg, channel_max])
        x=layers.Multiply()([inputs, channel_attention]); spatial_avg=tf.reduce_mean(x, axis=-1, keepdims=True); spatial_max=tf.reduce_max(x, axis=-1, keepdims=True)
        spatial_concat=tf.concat([spatial_avg, spatial_max], axis=-1); spatial_attention=self.conv2(self.conv1(spatial_concat))
        output=layers.Multiply()([x, spatial_attention]); return output
    def get_config(self):
        config = super(DualAttention3D, self).get_config()
        config.update({"reduction_ratio": self.reduction_ratio})
        return config

fusion_model_path = 'best_fusion_model.keras'
try:
    fusion_model = models.load_model(fusion_model_path, custom_objects={'DualAttention3D': DualAttention3D})
    print(f"Successfully loaded R²=0.88 model from {fusion_model_path}")
except Exception as e:
    print(f"--- ERROR: Could not load the fusion model {fusion_model_path} ---")
    print(f"Details: {e}")
    raise e 

# 2. Unfreeze the ENTIRE model
fusion_model.trainable = True
print(" =================== Successfully UNFROZE all layers in the model for fine-tuning =================== ")

# 3. Re-compile with a small learning rate for fine-tuning
FINE_TUNE_LR = 1e-5 
fusion_model.compile(optimizer=AdamW(learning_rate=FINE_TUNE_LR, weight_decay=1e-4),
                     loss='huber',
                     metrics=['mae'])

print(f"Model re-compiled with a fine-tuning learning rate of {FINE_TUNE_LR}")

# --- 7. TRAIN THE FINE-TUNED MODEL ---
print("\n =================== Fine-Tuning Final Fusion Model ===================")

final_model_name = 'To_Publish_Debye_Temperature_Best.h5'

callbacks = [
    EarlyStopping(monitor='val_loss', patience=50, restore_best_weights=True, verbose=1), 
    ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=20, min_lr=1e-8, verbose=1),
    ModelCheckpoint(final_model_name, monitor='val_loss', save_best_only=True, verbose=1)
]

history = fusion_model.fit(
    train_inputs, y_train,
    validation_data=(val_inputs, y_val),
    epochs=200, 
    batch_size=16, 
    callbacks=callbacks,
    verbose=1
)

print(f"Full fine-tuning complete. Best model saved to {final_model_name}")

# --- 8. EVALUATE THE FINE-TUNED MODEL ---
print("\n =================== Evaluating Full Fine-Tuned Model ===================")
y_pred_scaled = fusion_model.predict(test_inputs).flatten()

y_test_orig = scaler_y.inverse_transform(y_test.reshape(-1, 1)).flatten()
y_pred_orig = scaler_y.inverse_transform(y_pred_scaled.reshape(-1, 1)).flatten()

r2 = r2_score(y_test_orig, y_pred_orig)
mae = mean_absolute_error(y_test_orig, y_pred_orig)
rmse = np.sqrt(mean_squared_error(y_test_orig, y_pred_orig))

print("\n" + "="*60); 
print(" =================== REAL FINE-TUNE FINAL RESULTS ==================="); 
print("="*60)
print(f" R² Score:   {r2:.4f}"); 
print(f" MAE:        {mae:.4f} K"); 
print(f" RMSE:       {rmse:.4f} K")
print("="*60)

# --- 9. VISUALIZATION ---
print(" =================== Generating final plot =================== ")
plt.style.use('seaborn-v0_8-whitegrid')
plt.figure(figsize=(10, 8))

plt.scatter(y_test_orig, y_pred_orig, alpha=0.7, edgecolors='k', c='#e84393', s=60, label="Test Data (Real Fine-Tune)")
ideal_line = [min(y_test_orig.min(), y_pred_orig.min()), max(y_test_orig.max(), y_pred_orig.max())]
plt.plot(ideal_line, ideal_line, 'r--', lw=2.5, label="Ideal Fit")

metrics_text = (
    fr'$R^2$ = {r2:.4f}' + '\n' +
    fr'MAE = {mae:.2f} K' + '\n' +
    fr'RMSE = {rmse:.2f} K'
)
plt.text(0.05, 0.95, metrics_text, transform=plt.gca().transAxes,
         fontsize=14, verticalalignment='top', horizontalalignment='left',
         bbox=dict(facecolor='white', edgecolor='black', boxstyle='round,pad=0.5'))

plt.xlabel("Actual Debye Temperature", fontsize=14, fontweight='bold')
plt.ylabel("Predicted Debye Temperature", fontsize=14, fontweight='bold')
plt.title(r'Actual vs. Predicted', fontsize=16, fontweight='bold')
plt.legend(fontsize=12, loc='lower right')
plt.tight_layout()
plt.savefig("To_Publish_Debye_Temperature_Best.png", dpi=300)
plt.show()

print(f"Script complete. Final model saved to '{final_model_name}'")
# Out:
# !!! FORCING SCRIPT TO RUN ON GPU 0 ONLY !!!
# Enabled memory growth for 1 GPUs
#  =================== Starting Fine-Tuning ===================
# Successfully loaded '6059_rows.csv' and 'magpie_features.csv'
#  =================== Step 1/5: Aligning data sources ===================
#  =================== Step 2/5: Loading 3D .npy data ===================
#  =================== Step 3/5: Applying data cleaning ===================
# Final data shape after cleaning: (4736, 16, 16, 16, 16)
#  =================== Step 4/5: Scaling data ===================
# Data scaling complete.
#  =================== Step 5/5: Creating final data splits ===================
# 3D Train/Val/Test: (3030, 16, 16, 16, 16), (758, 16, 16, 16, 16), (948, 16, 16, 16, 16)
# Magpie Train/Val/Test: (3030, 132), (758, 132), (948, 132)
#  =================== Step 6/6: Loading and preparing model for Full Fine-Tuning ===================
# Successfully loaded R²=0.88 model from best_fusion_model.keras
#  =================== Successfully UNFROZE all layers in the model for fine-tuning ===================
# Model re-compiled with a fine-tuning learning rate of 1e-05
#
#  =================== Fine-Tuning Final Fusion Model ===================
# Epoch 1/200
# 2025-11-14 16:00:19.366608: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_16}}
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0138 - mae: 0.1265
# 2025-11-14 16:00:32.130328: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_16}}
# Epoch 1: val_loss improved from None to 0.00968, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 15s 49ms/step - loss: 0.0123 - mae: 0.1172 - val_loss: 0.0097 - val_mae: 0.0984 - learning_rate: 1.0000e-05
# Epoch 2/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0083 - mae: 0.0937
# Epoch 2: val_loss improved from 0.00968 to 0.00658, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0077 - mae: 0.0895 - val_loss: 0.0066 - val_mae: 0.0804 - learning_rate: 1.0000e-05
# Epoch 3/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0062 - mae: 0.0813
# Epoch 3: val_loss improved from 0.00658 to 0.00502, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0058 - mae: 0.0788 - val_loss: 0.0050 - val_mae: 0.0708 - learning_rate: 1.0000e-05
# Epoch 4/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0049 - mae: 0.0725
# Epoch 4: val_loss improved from 0.00502 to 0.00411, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0047 - mae: 0.0711 - val_loss: 0.0041 - val_mae: 0.0648 - learning_rate: 1.0000e-05
# Epoch 5/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0044 - mae: 0.0683
# Epoch 5: val_loss improved from 0.00411 to 0.00353, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0042 - mae: 0.0668 - val_loss: 0.0035 - val_mae: 0.0607 - learning_rate: 1.0000e-05
# Epoch 6/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0037 - mae: 0.0638
# Epoch 6: val_loss improved from 0.00353 to 0.00316, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0036 - mae: 0.0620 - val_loss: 0.0032 - val_mae: 0.0577 - learning_rate: 1.0000e-05
# Epoch 7/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0034 - mae: 0.0608
# Epoch 7: val_loss improved from 0.00316 to 0.00289, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0035 - mae: 0.0621 - val_loss: 0.0029 - val_mae: 0.0552 - learning_rate: 1.0000e-05
# Epoch 8/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0033 - mae: 0.0595
# Epoch 8: val_loss improved from 0.00289 to 0.00272, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0032 - mae: 0.0591 - val_loss: 0.0027 - val_mae: 0.0537 - learning_rate: 1.0000e-05
# Epoch 9/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0032 - mae: 0.0587
# Epoch 9: val_loss improved from 0.00272 to 0.00261, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0031 - mae: 0.0578 - val_loss: 0.0026 - val_mae: 0.0525 - learning_rate: 1.0000e-05
# Epoch 10/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0032 - mae: 0.0594
# Epoch 10: val_loss improved from 0.00261 to 0.00253, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0031 - mae: 0.0581 - val_loss: 0.0025 - val_mae: 0.0517 - learning_rate: 1.0000e-05
# Epoch 11/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0028 - mae: 0.0550
# Epoch 11: val_loss improved from 0.00253 to 0.00247, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0027 - mae: 0.0548 - val_loss: 0.0025 - val_mae: 0.0512 - learning_rate: 1.0000e-05
# Epoch 12/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0030 - mae: 0.0573
# Epoch 12: val_loss improved from 0.00247 to 0.00243, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0029 - mae: 0.0562 - val_loss: 0.0024 - val_mae: 0.0506 - learning_rate: 1.0000e-05
# Epoch 13/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0027 - mae: 0.0555
# Epoch 13: val_loss improved from 0.00243 to 0.00240, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0027 - mae: 0.0552 - val_loss: 0.0024 - val_mae: 0.0501 - learning_rate: 1.0000e-05
# Epoch 14/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0027 - mae: 0.0549
# Epoch 14: val_loss improved from 0.00240 to 0.00237, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0028 - mae: 0.0556 - val_loss: 0.0024 - val_mae: 0.0499 - learning_rate: 1.0000e-05
# Epoch 15/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0027 - mae: 0.0552
# Epoch 15: val_loss improved from 0.00237 to 0.00234, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0026 - mae: 0.0537 - val_loss: 0.0023 - val_mae: 0.0497 - learning_rate: 1.0000e-05
# Epoch 16/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0027 - mae: 0.0549
# Epoch 16: val_loss improved from 0.00234 to 0.00232, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0027 - mae: 0.0543 - val_loss: 0.0023 - val_mae: 0.0494 - learning_rate: 1.0000e-05
# Epoch 17/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0026 - mae: 0.0536
# Epoch 17: val_loss improved from 0.00232 to 0.00230, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0027 - mae: 0.0535 - val_loss: 0.0023 - val_mae: 0.0491 - learning_rate: 1.0000e-05
# Epoch 18/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0027 - mae: 0.0539
# Epoch 18: val_loss improved from 0.00230 to 0.00229, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0026 - mae: 0.0532 - val_loss: 0.0023 - val_mae: 0.0490 - learning_rate: 1.0000e-05
# Epoch 19/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 33ms/step - loss: 0.0025 - mae: 0.0522
# Epoch 19: val_loss improved from 0.00229 to 0.00227, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.0025 - mae: 0.0524 - val_loss: 0.0023 - val_mae: 0.0489 - learning_rate: 1.0000e-05
# Epoch 20/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0027 - mae: 0.0540
# Epoch 20: val_loss improved from 0.00227 to 0.00225, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0026 - mae: 0.0529 - val_loss: 0.0023 - val_mae: 0.0487 - learning_rate: 1.0000e-05
# Epoch 21/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0025 - mae: 0.0532
# Epoch 21: val_loss improved from 0.00225 to 0.00223, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0025 - mae: 0.0527 - val_loss: 0.0022 - val_mae: 0.0485 - learning_rate: 1.0000e-05
# Epoch 22/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0025 - mae: 0.0534
# Epoch 22: val_loss improved from 0.00223 to 0.00222, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0025 - mae: 0.0524 - val_loss: 0.0022 - val_mae: 0.0485 - learning_rate: 1.0000e-05
# Epoch 23/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0024 - mae: 0.0518
# Epoch 23: val_loss improved from 0.00222 to 0.00220, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0024 - mae: 0.0513 - val_loss: 0.0022 - val_mae: 0.0481 - learning_rate: 1.0000e-05
# Epoch 24/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0026 - mae: 0.0535
# Epoch 24: val_loss improved from 0.00220 to 0.00219, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0025 - mae: 0.0524 - val_loss: 0.0022 - val_mae: 0.0480 - learning_rate: 1.0000e-05
# Epoch 25/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0024 - mae: 0.0515
# Epoch 25: val_loss improved from 0.00219 to 0.00217, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0024 - mae: 0.0513 - val_loss: 0.0022 - val_mae: 0.0478 - learning_rate: 1.0000e-05
# Epoch 26/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0025 - mae: 0.0531
# Epoch 26: val_loss improved from 0.00217 to 0.00216, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0025 - mae: 0.0522 - val_loss: 0.0022 - val_mae: 0.0477 - learning_rate: 1.0000e-05
# Epoch 27/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0024 - mae: 0.0518
# Epoch 27: val_loss improved from 0.00216 to 0.00215, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0025 - mae: 0.0515 - val_loss: 0.0021 - val_mae: 0.0476 - learning_rate: 1.0000e-05
# Epoch 28/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0024 - mae: 0.0510
# Epoch 28: val_loss improved from 0.00215 to 0.00214, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0024 - mae: 0.0507 - val_loss: 0.0021 - val_mae: 0.0475 - learning_rate: 1.0000e-05
# Epoch 29/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0023 - mae: 0.0500
# Epoch 29: val_loss improved from 0.00214 to 0.00213, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0023 - mae: 0.0506 - val_loss: 0.0021 - val_mae: 0.0474 - learning_rate: 1.0000e-05
# Epoch 30/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0023 - mae: 0.0502
# Epoch 30: val_loss improved from 0.00213 to 0.00211, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0023 - mae: 0.0496 - val_loss: 0.0021 - val_mae: 0.0474 - learning_rate: 1.0000e-05
# Epoch 31/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0023 - mae: 0.0500
# Epoch 31: val_loss improved from 0.00211 to 0.00210, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0024 - mae: 0.0503 - val_loss: 0.0021 - val_mae: 0.0472 - learning_rate: 1.0000e-05
# Epoch 32/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0022 - mae: 0.0492
# Epoch 32: val_loss improved from 0.00210 to 0.00209, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0023 - mae: 0.0500 - val_loss: 0.0021 - val_mae: 0.0471 - learning_rate: 1.0000e-05
# Epoch 33/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0023 - mae: 0.0507
# Epoch 33: val_loss improved from 0.00209 to 0.00208, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0022 - mae: 0.0497 - val_loss: 0.0021 - val_mae: 0.0470 - learning_rate: 1.0000e-05
# Epoch 34/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0022 - mae: 0.0495
# Epoch 34: val_loss improved from 0.00208 to 0.00207, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0023 - mae: 0.0500 - val_loss: 0.0021 - val_mae: 0.0469 - learning_rate: 1.0000e-05
# Epoch 35/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0023 - mae: 0.0500
# Epoch 35: val_loss improved from 0.00207 to 0.00206, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0023 - mae: 0.0501 - val_loss: 0.0021 - val_mae: 0.0467 - learning_rate: 1.0000e-05
# Epoch 36/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0022 - mae: 0.0487
# Epoch 36: val_loss improved from 0.00206 to 0.00205, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0022 - mae: 0.0487 - val_loss: 0.0020 - val_mae: 0.0466 - learning_rate: 1.0000e-05
# Epoch 37/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0022 - mae: 0.0493
# Epoch 37: val_loss improved from 0.00205 to 0.00204, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0023 - mae: 0.0497 - val_loss: 0.0020 - val_mae: 0.0465 - learning_rate: 1.0000e-05
# Epoch 38/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0021 - mae: 0.0478
# Epoch 38: val_loss improved from 0.00204 to 0.00204, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0021 - mae: 0.0485 - val_loss: 0.0020 - val_mae: 0.0464 - learning_rate: 1.0000e-05
# Epoch 39/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0022 - mae: 0.0486
# Epoch 39: val_loss improved from 0.00204 to 0.00202, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0022 - mae: 0.0488 - val_loss: 0.0020 - val_mae: 0.0465 - learning_rate: 1.0000e-05
# Epoch 40/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0021 - mae: 0.0482
# Epoch 40: val_loss improved from 0.00202 to 0.00202, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0022 - mae: 0.0492 - val_loss: 0.0020 - val_mae: 0.0462 - learning_rate: 1.0000e-05
# Epoch 41/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0021 - mae: 0.0483
# Epoch 41: val_loss improved from 0.00202 to 0.00201, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0022 - mae: 0.0486 - val_loss: 0.0020 - val_mae: 0.0462 - learning_rate: 1.0000e-05
# Epoch 42/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0021 - mae: 0.0491
# Epoch 42: val_loss did not improve from 0.00201
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 38ms/step - loss: 0.0021 - mae: 0.0485 - val_loss: 0.0020 - val_mae: 0.0461 - learning_rate: 1.0000e-05
# Epoch 43/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0023 - mae: 0.0500
# Epoch 43: val_loss improved from 0.00201 to 0.00200, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 0.0022 - mae: 0.0488 - val_loss: 0.0020 - val_mae: 0.0462 - learning_rate: 1.0000e-05
# Epoch 44/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0021 - mae: 0.0489
# Epoch 44: val_loss improved from 0.00200 to 0.00200, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0022 - mae: 0.0488 - val_loss: 0.0020 - val_mae: 0.0461 - learning_rate: 1.0000e-05
# Epoch 45/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0021 - mae: 0.0483
# Epoch 45: val_loss improved from 0.00200 to 0.00199, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0022 - mae: 0.0487 - val_loss: 0.0020 - val_mae: 0.0461 - learning_rate: 1.0000e-05
# Epoch 46/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0021 - mae: 0.0489
# Epoch 46: val_loss improved from 0.00199 to 0.00199, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0021 - mae: 0.0485 - val_loss: 0.0020 - val_mae: 0.0461 - learning_rate: 1.0000e-05
# Epoch 47/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0021 - mae: 0.0476
# Epoch 47: val_loss improved from 0.00199 to 0.00198, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 0.0021 - mae: 0.0482 - val_loss: 0.0020 - val_mae: 0.0460 - learning_rate: 1.0000e-05
# Epoch 48/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0020 - mae: 0.0471
# Epoch 48: val_loss improved from 0.00198 to 0.00198, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0020 - mae: 0.0470 - val_loss: 0.0020 - val_mae: 0.0459 - learning_rate: 1.0000e-05
# Epoch 49/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0020 - mae: 0.0471
# Epoch 49: val_loss improved from 0.00198 to 0.00197, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 0.0021 - mae: 0.0476 - val_loss: 0.0020 - val_mae: 0.0458 - learning_rate: 1.0000e-05
# Epoch 50/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0020 - mae: 0.0471
# Epoch 50: val_loss improved from 0.00197 to 0.00197, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0021 - mae: 0.0478 - val_loss: 0.0020 - val_mae: 0.0457 - learning_rate: 1.0000e-05
# Epoch 51/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0021 - mae: 0.0487
# Epoch 51: val_loss did not improve from 0.00197
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0021 - mae: 0.0473 - val_loss: 0.0020 - val_mae: 0.0457 - learning_rate: 1.0000e-05
# Epoch 52/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0021 - mae: 0.0477
# Epoch 52: val_loss improved from 0.00197 to 0.00196, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0021 - mae: 0.0477 - val_loss: 0.0020 - val_mae: 0.0457 - learning_rate: 1.0000e-05
# Epoch 53/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0020 - mae: 0.0477
# Epoch 53: val_loss improved from 0.00196 to 0.00195, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 0.0020 - mae: 0.0475 - val_loss: 0.0020 - val_mae: 0.0457 - learning_rate: 1.0000e-05
# Epoch 54/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0020 - mae: 0.0469
# Epoch 54: val_loss improved from 0.00195 to 0.00195, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0021 - mae: 0.0476 - val_loss: 0.0020 - val_mae: 0.0456 - learning_rate: 1.0000e-05
# Epoch 55/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0020 - mae: 0.0476
# Epoch 55: val_loss improved from 0.00195 to 0.00194, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0020 - mae: 0.0476 - val_loss: 0.0019 - val_mae: 0.0455 - learning_rate: 1.0000e-05
# Epoch 56/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0020 - mae: 0.0472
# Epoch 56: val_loss improved from 0.00194 to 0.00194, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0020 - mae: 0.0468 - val_loss: 0.0019 - val_mae: 0.0455 - learning_rate: 1.0000e-05
# Epoch 57/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0020 - mae: 0.0472
# Epoch 57: val_loss improved from 0.00194 to 0.00194, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0020 - mae: 0.0469 - val_loss: 0.0019 - val_mae: 0.0454 - learning_rate: 1.0000e-05
# Epoch 58/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0019 - mae: 0.0466
# Epoch 58: val_loss improved from 0.00194 to 0.00193, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0020 - mae: 0.0466 - val_loss: 0.0019 - val_mae: 0.0454 - learning_rate: 1.0000e-05
# Epoch 59/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0019 - mae: 0.0455
# Epoch 59: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
#
# Epoch 59: val_loss did not improve from 0.00193
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0019 - mae: 0.0460 - val_loss: 0.0019 - val_mae: 0.0453 - learning_rate: 1.0000e-05
# Epoch 60/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0020 - mae: 0.0470
# Epoch 60: val_loss did not improve from 0.00193
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 0.0021 - mae: 0.0480 - val_loss: 0.0019 - val_mae: 0.0454 - learning_rate: 5.0000e-06
# Epoch 61/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0019 - mae: 0.0458
# Epoch 61: val_loss improved from 0.00193 to 0.00193, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 44ms/step - loss: 0.0020 - mae: 0.0466 - val_loss: 0.0019 - val_mae: 0.0454 - learning_rate: 5.0000e-06
# Epoch 62/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0019 - mae: 0.0460
# Epoch 62: val_loss improved from 0.00193 to 0.00193, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0019 - mae: 0.0462 - val_loss: 0.0019 - val_mae: 0.0453 - learning_rate: 5.0000e-06
# Epoch 63/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0020 - mae: 0.0463
# Epoch 63: val_loss improved from 0.00193 to 0.00192, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0020 - mae: 0.0465 - val_loss: 0.0019 - val_mae: 0.0453 - learning_rate: 5.0000e-06
# Epoch 64/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0020 - mae: 0.0465
# Epoch 64: val_loss did not improve from 0.00192
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0020 - mae: 0.0468 - val_loss: 0.0019 - val_mae: 0.0453 - learning_rate: 5.0000e-06
# Epoch 65/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0019 - mae: 0.0460
# Epoch 65: val_loss improved from 0.00192 to 0.00192, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0018 - mae: 0.0450 - val_loss: 0.0019 - val_mae: 0.0453 - learning_rate: 5.0000e-06
# Epoch 66/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0019 - mae: 0.0450
# Epoch 66: val_loss improved from 0.00192 to 0.00192, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0019 - mae: 0.0455 - val_loss: 0.0019 - val_mae: 0.0453 - learning_rate: 5.0000e-06
# Epoch 67/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0019 - mae: 0.0459
# Epoch 67: val_loss did not improve from 0.00192
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0019 - mae: 0.0454 - val_loss: 0.0019 - val_mae: 0.0452 - learning_rate: 5.0000e-06
# Epoch 68/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0449
# Epoch 68: val_loss improved from 0.00192 to 0.00192, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0019 - mae: 0.0456 - val_loss: 0.0019 - val_mae: 0.0452 - learning_rate: 5.0000e-06
# Epoch 69/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0019 - mae: 0.0458
# Epoch 69: val_loss improved from 0.00192 to 0.00191, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0019 - mae: 0.0457 - val_loss: 0.0019 - val_mae: 0.0451 - learning_rate: 5.0000e-06
# Epoch 70/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0020 - mae: 0.0463
# Epoch 70: val_loss improved from 0.00191 to 0.00191, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0019 - mae: 0.0454 - val_loss: 0.0019 - val_mae: 0.0451 - learning_rate: 5.0000e-06
# Epoch 71/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0018 - mae: 0.0442
# Epoch 71: val_loss improved from 0.00191 to 0.00191, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0019 - mae: 0.0453 - val_loss: 0.0019 - val_mae: 0.0451 - learning_rate: 5.0000e-06
# Epoch 72/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0449
# Epoch 72: val_loss improved from 0.00191 to 0.00191, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0019 - mae: 0.0449 - val_loss: 0.0019 - val_mae: 0.0451 - learning_rate: 5.0000e-06
# Epoch 73/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0019 - mae: 0.0462
# Epoch 73: val_loss did not improve from 0.00191
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0019 - mae: 0.0456 - val_loss: 0.0019 - val_mae: 0.0450 - learning_rate: 5.0000e-06
# Epoch 74/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0020 - mae: 0.0470
# Epoch 74: val_loss did not improve from 0.00191
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 0.0019 - mae: 0.0463 - val_loss: 0.0019 - val_mae: 0.0450 - learning_rate: 5.0000e-06
# Epoch 75/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0449
# Epoch 75: val_loss improved from 0.00191 to 0.00190, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0019 - mae: 0.0458 - val_loss: 0.0019 - val_mae: 0.0450 - learning_rate: 5.0000e-06
# Epoch 76/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0018 - mae: 0.0453
# Epoch 76: val_loss improved from 0.00190 to 0.00190, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0018 - mae: 0.0448 - val_loss: 0.0019 - val_mae: 0.0450 - learning_rate: 5.0000e-06
# Epoch 77/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0446
# Epoch 77: val_loss did not improve from 0.00190
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0018 - mae: 0.0448 - val_loss: 0.0019 - val_mae: 0.0449 - learning_rate: 5.0000e-06
# Epoch 78/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0019 - mae: 0.0461
# Epoch 78: val_loss improved from 0.00190 to 0.00190, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0019 - mae: 0.0459 - val_loss: 0.0019 - val_mae: 0.0449 - learning_rate: 5.0000e-06
# Epoch 79/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0451
# Epoch 79: val_loss improved from 0.00190 to 0.00190, saving model to To_Publish_Debye_Temperature_Best.h5
# ...
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 7s 39ms/step - loss: 0.0018 - mae: 0.0445 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 170/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0456
# Epoch 170: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0018 - mae: 0.0448 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 171/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0456
# Epoch 171: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0019 - mae: 0.0458 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 172/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0017 - mae: 0.0438
# Epoch 172: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0017 - mae: 0.0441 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 173/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0444
# Epoch 173: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0018 - mae: 0.0443 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 174/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0450
# Epoch 174: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0018 - mae: 0.0445 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 175/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0453
# Epoch 175: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0018 - mae: 0.0448 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 176/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0446
# Epoch 176: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0018 - mae: 0.0445 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 177/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0018 - mae: 0.0437
# Epoch 177: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0018 - mae: 0.0447 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 178/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0018 - mae: 0.0442
# Epoch 178: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0018 - mae: 0.0444 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 179/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0447
# Epoch 179: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0018 - mae: 0.0445 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 180/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 34ms/step - loss: 0.0017 - mae: 0.0433
# Epoch 180: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0018 - mae: 0.0440 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 181/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0444
# Epoch 181: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 39ms/step - loss: 0.0018 - mae: 0.0441 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 182/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0442
# Epoch 182: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0018 - mae: 0.0443 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 183/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0018 - mae: 0.0449
# Epoch 183: ReduceLROnPlateau reducing learning rate to 7.81249980263965e-08.
#
# Epoch 183: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0018 - mae: 0.0443 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 1.5625e-07
# Epoch 184/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0444
# Epoch 184: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0018 - mae: 0.0449 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 185/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0017 - mae: 0.0435
# Epoch 185: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0017 - mae: 0.0436 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 186/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0446
# Epoch 186: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0019 - mae: 0.0450 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 187/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0454
# Epoch 187: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0018 - mae: 0.0452 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 188/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0446
# Epoch 188: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0017 - mae: 0.0439 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 189/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0443
# Epoch 189: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0018 - mae: 0.0446 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 190/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0019 - mae: 0.0452
# Epoch 190: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0019 - mae: 0.0453 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 191/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0440
# Epoch 191: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0017 - mae: 0.0437 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 192/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0017 - mae: 0.0437
# Epoch 192: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0018 - mae: 0.0446 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 193/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0018 - mae: 0.0446
# Epoch 193: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0018 - mae: 0.0449 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 194/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0018 - mae: 0.0448
# Epoch 194: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0018 - mae: 0.0442 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 195/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0018 - mae: 0.0444
# Epoch 195: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0018 - mae: 0.0443 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 196/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step - loss: 0.0018 - mae: 0.0449
# Epoch 196: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0018 - mae: 0.0444 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 197/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0455
# Epoch 197: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 43ms/step - loss: 0.0019 - mae: 0.0454 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 198/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0437
# Epoch 198: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 41ms/step - loss: 0.0018 - mae: 0.0446 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 199/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0019 - mae: 0.0451
# Epoch 199: val_loss improved from 0.00186 to 0.00186, saving model to To_Publish_Debye_Temperature_Best.h5
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 42ms/step - loss: 0.0019 - mae: 0.0448 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Epoch 200/200
# 189/190 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step - loss: 0.0018 - mae: 0.0440
# Epoch 200: val_loss did not improve from 0.00186
# 190/190 ━━━━━━━━━━━━━━━━━━━━ 8s 40ms/step - loss: 0.0018 - mae: 0.0449 - val_loss: 0.0019 - val_mae: 0.0444 - learning_rate: 7.8125e-08
# Restoring model weights from the end of the best epoch: 199.
# Full fine-tuning complete. Best model saved to To_Publish_Debye_Temperature_Best.h5
#
#  =================== Evaluating Full Fine-Tuned Model ===================
# 2025-11-14 16:26:47.027422: E tensorflow/core/framework/node_def_util.cc:680] NodeDef mentions attribute use_unbounded_threadpool which is not in the op definition: Op<name=MapDataset; signature=input_dataset:variant, other_arguments: -> handle:variant; attr=f:func; attr=Targuments:list(type),min=0; attr=output_types:list(type),min=1; attr=output_shapes:list(shape),min=1; attr=use_inter_op_parallelism:bool,default=true; attr=preserve_cardinality:bool,default=false; attr=force_synchronous:bool,default=false; attr=metadata:string,default=""> This may be expected if your graph generating binary is newer  than this binary. Unknown attributes will be ignored. NodeDef: {{node ParallelMapDatasetV2/_15}}
# 30/30 ━━━━━━━━━━━━━━━━━━━━ 2s 36ms/step
#
# ============================================================
#  =================== REAL FINE-TUNE FINAL RESULTS ===================
# ============================================================
#  R² Score:   0.9030
#  MAE:        28.4682 K
#  RMSE:       39.3394 K
# ============================================================
#  =================== Generating final plot ===================
# Script complete. Final model saved to 'To_Publish_Debye_Temperature_Best.h5'
